# %% [markdown]
# <a href="https://colab.research.google.com/github/MirzaUmar1/SIC-Artificial-Intelligence/blob/main/Lab%20Tasks/SICLabTasks12a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Practice Tasks**

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('/content/data_studentlist.csv')

# %%
df.head()
# Out:
#               name gender  age  grade absence bloodtype  height  weight
# 0    Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1   Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2     Brian Martin      M   24      4       N         B   175.0    80.1
# 3     David Hassel      M   23      3       N        AB   182.1    85.7
# 4  Clara Rodriquez      F   20      1       Y         A   168.0    49.5

# %% [markdown]
# ##**Access Specific Columns:**

# %% [markdown]
# ###**How can you retrieve and display only the name and age columns from the DataFrame? Write the code to accomplish this.**

# %%
filtered_df = df[['name', 'age']]
print(filtered_df)
# Out:
#                 name  age
# 0      Jared Diamond   23
# 1     Sarah O'Donnel   22
# 2       Brian Martin   24
# 3       David Hassel   23
# 4    Clara Rodriquez   20
# 5   Jennifer Lorentz   21
# 6        Susan Clark   22
# 7    Margareth Jones   23
# 8       John Bertsch   23
# 9     Jake Timmerman   22
# 10     Joshua Connor   24
# 11      John Matsuda   22
# 12      Eddy Johnson   21
# 13  Rebecah Anderson   23
# 14      Linda Carter   22
# 15    Richard Swayze   24
# 16       Andrew King   21

# %% [markdown]
# ##**Access Specific Rows:**

# %% [markdown]
# ###**What method would you use to access the first three rows of the DataFrame? Write the code to access and print the last two rows.**

# %%
df.head(3)
# Out:
#              name gender  age  grade absence bloodtype  height  weight
# 0   Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1  Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2    Brian Martin      M   24      4       N         B   175.0    80.1

# %%
df.tail(2)
# Out:
#               name gender  age  grade absence bloodtype  height  weight
# 15  Richard Swayze      M   24      4       Y         B   168.6    70.2
# 16     Andrew King      M   21      1       N         A   169.2    62.2

# %% [markdown]
# ##**Access a Specific Cell:**

# %% [markdown]
# ###**How can you access the grade of the student located in the second row (index 1) of the DataFrame? Provide the code for this operation.**

# %%
df.loc[1, 'grade']
# Out:
# 2

# %% [markdown]
# ##**Using loc to Filter Data:**

# %% [markdown]
# ###**Write a command using the loc method to filter and display the names and grades of students who are older than 15 years.**

# %%
df.loc[df['age'] > 15, ['name', 'grade']]
# Out:
#                 name  grade
# 0      Jared Diamond      3
# 1     Sarah O'Donnel      2
# 2       Brian Martin      4
# 3       David Hassel      3
# 4    Clara Rodriquez      1
# 5   Jennifer Lorentz      2
# 6        Susan Clark      1
# 7    Margareth Jones      1
# 8       John Bertsch      3
# 9     Jake Timmerman      2
# 10     Joshua Connor      4
# 11      John Matsuda      2
# 12      Eddy Johnson      1
# 13  Rebecah Anderson      3
# 14      Linda Carter      2
# 15    Richard Swayze      4
# 16       Andrew King      1

# %% [markdown]
# ##**Count Unique Values:**

# %% [markdown]
# ###**How can you determine the number of unique blood types present in the dataset? Provide the code to count and print the unique blood types.**

# %%
df.loc[:, 'bloodtype'].nunique()
# Out:
# 4

# %%
df.loc[:, 'bloodtype'].unique()
# Out:
# array(['O', 'AB', 'B', 'A'], dtype=object)

# %% [markdown]
# ##**Calculate Average Height:**

# %% [markdown]
# ###**What is the method to calculate the average height of students in the DataFrame? Write the code to compute and display this average.**

# %%
df.height.mean()
# Out:
# 170.03529411764703

# %% [markdown]
# ##**Group By and Aggregate:**

# %% [markdown]
# ###**How can you group the data by gender and calculate the average age for each gender? Write the code to perform this aggregation and print the results.**

# %%
df.groupby('gender')['age'].mean()
# Out:
# gender
# F    21.857143
# M    22.700000
# Name: age, dtype: float64

# %% [markdown]
# ##**Create a New Column:**

# %% [markdown]
# ###**Explain how you would create a new column named BMI in the DataFrame, calculated as weight (kg) divided by the square of height (m). Provide the code for adding this new column and display the updated DataFrame.**

# %%
df['BMI'] = df['weight'] / (df['height'] ** 2)
df.head()
# Out:
#               name gender  age  grade absence bloodtype  height  weight  \
# 0    Jared Diamond      M   23      3       Y         O   165.3    68.2
# 1   Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 2     Brian Martin      M   24      4       N         B   175.0    80.1
# 3     David Hassel      M   23      3       N        AB   182.1    85.7
# 4  Clara Rodriquez      F   20      1       Y         A   168.0    49.5
#
#         BMI
# 0  0.002496
# 1  0.001832
# 2  0.002616
# 3  0.002584
# 4  0.001754
